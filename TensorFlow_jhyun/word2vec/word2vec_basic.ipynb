# %%
from __future__ import absolute_import
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = f.read(f.namelist()[0]).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], '->', labels[i, 0])
  print(reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i, 0]])
# Out:
# 3084 -> 12
# originated -> as
# 3084 -> 5239
# originated -> anarchism
# 12 -> 3084
# as -> originated
# 12 -> 6
# as -> a
# 6 -> 12
# a -> as
# 6 -> 195
# a -> term
# 195 -> 2
# term -> of
# 195 -> 6
# term -> a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

# %%
with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                       num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    tf.initialize_all_variables().run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  322.075622559
# Nearest to such: drum, moth, immigrated, lowering, floyd, alg, difficult, eustace,
# Nearest to all: luxemburg, pose, attachments, satem, phi, dems, blackwell, christa,
# Nearest to at: tightly, ditko, asbury, denise, typed, zal, bushy, fruitful,
# Nearest to they: proportion, bleaching, stirling, niven, fetching, waning, foote, rocking,
# Nearest to or: wells, buena, plummer, gameplay, espresso, populated, passengers, czechs,
# Nearest to it: mulatto, jury, bronte, confront, grandfather, slice, await, captive,
# Nearest to zero: canceling, caused, parked, amerindians, cana, jubal, mississippi, missa,
# Nearest to four: avoid, pleading, antics, cinematographers, eroded, tatar, order, cohesion,
# Nearest to eight: bes, gamblers, iterative, broth, nyc, jamestown, carmel, arminius,
# Nearest to may: atmosphere, sensei, altruism, settle, extrusive, grasped, cline, burgh,
# Nearest to were: marginally, sovereign, reforms, exposures, reconciled, ethic, lingers, amicable,
# Nearest to that: bertram, jared, corrupt, proxy, precede, spectroscopic, hegelian, bitten,
# Nearest to over: lo, aosta, beaches, gallico, incomparable, invoked, rational, clothes,
# Nearest to war: farian, atman, arin, conservatives, angiotensin, positives, rowe, acf,
# Nearest to used: ptc, shorty, airport, edsger, intentions, underwear, miserably, oxymoron,
# Nearest to th: conspired, melt, ozzfest, estas, summon, wrap, flattered, vestry,
# Average loss at step  2000 :  113.841014622
# Average loss at step  4000 :  52.7030357687
# Average loss at step  6000 :  33.3963392844
# Average loss at step  8000 :  23.1381101773
# Average loss at step  10000 :  18.0449258215
# Nearest to such: drum, difficult, floyd, vs, frequent, sandstone, needless, lowering,
# Nearest to all: phi, rates, three, pose, divine, sheets, member, cancer,
# Nearest to at: of, in, arthur, and, europe, tightly, strait, suffered,
# Nearest to they: proportion, var, einstein, waiting, aberdeen, atomic, protection, burial,
# Nearest to or: and, gollancz, buena, wells, victoriae, analogue, gameplay, gland,
# Nearest to it: he, altenberg, grandfather, probably, equation, often, and, oh,
# Nearest to zero: nine, aberdeen, vs, six, victoriae, mathbf, gland, eight,
# Nearest to four: nine, one, vs, zero, gollancz, avoid, aberdeen, needing,
# Nearest to eight: zero, nine, victoriae, vs, gland, agave, phi, reginae,
# Nearest to may: atmosphere, sensei, altruism, brand, methyl, douglas, january, trail,
# Nearest to were: stranger, but, jurisdiction, mathbf, and, targeted, alkali, had,
# Nearest to that: countries, and, spectroscopic, victoriae, solf, corrupt, in, on,
# Nearest to over: rational, hyacinthus, fao, novel, beaches, collectively, scenic, six,
# Nearest to war: anxiety, before, plateau, conservatives, uncertainty, constellations, aaron, term,
# Nearest to used: airport, sunda, vice, both, supplying, runner, saskatchewan, cl,
# Nearest to th: zero, nine, ignosticism, aberdeen, finalist, four, five, vs,
# Average loss at step  12000 :  13.8760815412
# Average loss at step  14000 :  11.7342466434
# Average loss at step  16000 :  9.82546450782
# Average loss at step  18000 :  8.78931943047
# Average loss at step  20000 :  7.81889250779
# Nearest to such: drum, needless, hbox, frequent, difficult, floyd, vs, uncovered,
# Nearest to all: phi, rates, pose, aoc, three, member, divine, sheets,
# Nearest to at: in, and, of, seven, dasyprocta, arthur, from, nine,
# Nearest to they: absalom, lipids, he, proportion, it, var, burial, waiting,
# Nearest to or: and, gollancz, the, victoriae, six, in, buena, zero,
# Nearest to it: he, this, and, altenberg, not, equation, probably, often,
# Nearest to zero: nine, eight, five, six, three, seven, two, dasyprocta,
# Nearest to four: zero, five, nine, two, three, eight, six, seven,
# Nearest to eight: nine, zero, six, five, seven, three, two, victoriae,
# Nearest to may: atmosphere, can, sensei, altruism, brand, january, methyl, haliotis,
# Nearest to were: are, was, had, but, and, is, by, stranger,
# Nearest to that: which, but, and, victoriae, in, countries, corrupt, zorn,
# Nearest to over: rational, fao, hyacinthus, novel, six, beaches, lo, collectively,
# Nearest to war: melisende, anxiety, before, uncertainty, plateau, agouti, dasyprocta, conservatives,
# Nearest to used: airport, glycerol, supplying, canonical, appalachia, protector, evaluate, both,
# Nearest to th: zero, dasyprocta, five, four, seven, nine, six, ignosticism,
# Average loss at step  22000 :  7.12381253791
# Average loss at step  24000 :  7.11265964043
# Average loss at step  26000 :  6.73973796487
# Average loss at step  28000 :  6.0928277365
# Average loss at step  30000 :  6.21040087175
# Nearest to such: needless, drum, immigrated, monochromatic, frequent, difficult, primigenius, tines,
# Nearest to all: phi, rates, pose, aoc, member, cretan, gnu, three,
# Nearest to at: in, and, from, seven, dasyprocta, on, karloff, five,
# Nearest to they: he, it, you, absalom, there, not, lipids, we,
# Nearest to or: and, gollancz, primigenius, agouti, victoriae, gland, dasyprocta, nine,
# Nearest to it: he, this, not, she, altenberg, which, also, they,
# Nearest to zero: five, eight, seven, six, nine, four, three, dasyprocta,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to eight: nine, six, five, seven, four, three, zero, two,
# Nearest to may: can, atmosphere, would, sensei, must, altruism, brand, january,
# Nearest to were: are, was, had, by, is, but, have, and,
# Nearest to that: which, victoriae, but, countries, napster, sine, zorn, spectroscopic,
# Nearest to over: rational, fao, aosta, hyacinthus, novel, six, from, when,
# Nearest to war: angiotensin, melisende, anxiety, atman, before, uncertainty, plateau, arin,
# Nearest to used: primigenius, supplying, heterosexuals, airport, ptc, canonical, evaluate, glycerol,
# Nearest to th: five, seven, four, zero, eight, six, dasyprocta, three,
# Average loss at step  32000 :  5.85423269963
# Average loss at step  34000 :  5.87402987409
# Average loss at step  36000 :  5.68099098086
# Average loss at step  38000 :  5.25607175446
# Average loss at step  40000 :  5.47593465745
# Nearest to such: hus, needless, primigenius, drum, tines, low, monochromatic, hbox,
# Nearest to all: phi, rates, two, three, aoc, pose, gnu, cretan,
# Nearest to at: in, on, from, dasyprocta, karloff, and, alpina, seven,
# Nearest to they: he, it, you, there, we, not, absalom, lipids,
# Nearest to or: and, six, eight, three, gollancz, victoriae, dasyprocta, primigenius,
# Nearest to it: he, this, she, which, not, there, they, altenberg,
# Nearest to zero: seven, eight, five, six, nine, four, three, dasyprocta,
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to eight: nine, seven, six, five, zero, four, three, dasyprocta,
# Nearest to may: can, would, atmosphere, must, sensei, could, altruism, january,
# Nearest to were: are, was, have, had, but, is, by, purity,
# Nearest to that: which, but, this, victoriae, it, dasyprocta, however, napster,
# Nearest to over: fao, rational, aosta, hyacinthus, troposphere, from, novel, six,
# Nearest to war: angiotensin, atman, anxiety, farian, melisende, before, uncertainty, albeit,
# Nearest to used: primigenius, heterosexuals, supplying, ptc, recitative, canonical, evaluate, therapeutic,
# Nearest to th: seven, four, six, zero, eight, five, dasyprocta, nine,
# Average loss at step  42000 :  5.33491976678
# Average loss at step  44000 :  5.2890715853
# Average loss at step  46000 :  5.28555425429
# Average loss at step  48000 :  5.03379954875
# Average loss at step  50000 :  5.15083422959
# Nearest to such: hus, needless, abiding, low, tines, well, frequent, immigrated,
# Nearest to all: phi, rates, dems, three, two, aoc, gnu, most,
# Nearest to at: in, on, from, dasyprocta, seven, after, karloff, gollancz,
# Nearest to they: he, you, it, we, there, not, burial, exhibits,
# Nearest to or: and, heckel, dasyprocta, primigenius, six, three, gollancz, agouti,
# Nearest to it: he, this, she, there, which, altenberg, they, not,
# Nearest to zero: seven, five, eight, six, nine, four, three, dasyprocta,
# Nearest to four: six, three, five, eight, seven, two, one, zero,
# Nearest to eight: six, nine, seven, four, five, three, zero, one,
# Nearest to may: can, would, must, could, atmosphere, sensei, january, altruism,
# Nearest to were: are, was, have, had, is, but, by, thibetanus,
# Nearest to that: which, but, fanzines, however, this, victoriae, prism, because,
# Nearest to over: rational, fao, aosta, hyacinthus, when, novel, troposphere, comprising,
# Nearest to war: angiotensin, atman, farian, anxiety, melisende, before, uncertainty, boaz,
# Nearest to used: primigenius, heterosexuals, ptc, supplying, evaluate, therapeutic, recitative, canonical,
# Nearest to th: seven, eight, six, four, three, five, dasyprocta, zero,
# Average loss at step  52000 :  5.18128785932
# Average loss at step  54000 :  5.12968699396
# Average loss at step  56000 :  5.05917211759
# Average loss at step  58000 :  5.10916249859
# Average loss at step  60000 :  4.95355439329
# Nearest to such: hus, these, abiding, needless, well, tines, reels, regarded,
# Nearest to all: wct, rates, microcebus, phi, dems, three, two, gnu,
# Nearest to at: in, on, callithrix, after, dasyprocta, throughout, from, under,
# Nearest to they: he, you, there, we, it, not, microseconds, who,
# Nearest to or: and, callithrix, microcebus, michelob, dasyprocta, cebus, than, primigenius,
# Nearest to it: he, this, she, there, which, they, altenberg, michelob,
# Nearest to zero: five, eight, six, seven, four, nine, three, callithrix,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Nearest to eight: nine, six, seven, five, four, zero, three, microcebus,
# Nearest to may: can, would, must, could, will, atmosphere, sensei, january,
# Nearest to were: are, was, had, have, but, callithrix, is, thibetanus,
# Nearest to that: which, this, but, prism, wct, victoriae, however, callithrix,
# Nearest to over: wct, hyacinthus, fao, when, aosta, rational, troposphere, comprising,
# Nearest to war: angiotensin, atman, farian, anxiety, melisende, before, boaz, plateau,
# Nearest to used: primigenius, heterosexuals, microcebus, ptc, therapeutic, known, supplying, recitative,
# Nearest to th: four, eight, five, seven, six, nine, zero, three,
# Average loss at step  62000 :  4.79430361634
# Average loss at step  64000 :  4.77914393365
# Average loss at step  66000 :  4.96726437581
# Average loss at step  68000 :  4.91871097934
# Average loss at step  70000 :  4.76918679428
# Nearest to such: these, hus, well, abiding, tines, needless, regarded, reels,
# Nearest to all: wct, dinar, rates, dems, phi, microcebus, gnu, both,
# Nearest to at: in, on, callithrix, after, dasyprocta, during, zorn, between,
# Nearest to they: he, you, there, we, it, not, who, microseconds,
# Nearest to or: and, callithrix, michelob, cebus, dinar, microcebus, than, dasyprocta,
# Nearest to it: he, this, she, there, which, they, thaler, altenberg,
# Nearest to zero: six, eight, five, seven, four, nine, three, callithrix,
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to eight: nine, seven, six, four, five, three, zero, microcebus,
# Nearest to may: can, would, must, could, will, atmosphere, sensei, january,
# Nearest to were: are, was, have, had, be, is, thaler, been,
# Nearest to that: which, this, but, however, wct, callithrix, prism, victoriae,
# Nearest to over: wct, when, hyacinthus, rational, troposphere, aosta, fao, comprising,
# Nearest to war: angiotensin, atman, farian, anxiety, melisende, before, boaz, plateau,
# Nearest to used: primigenius, microcebus, heterosexuals, known, therapeutic, considered, recitative, marmoset,
# Nearest to th: four, six, eight, seven, five, zero, nine, three,
# Average loss at step  72000 :  4.81395413506
# Average loss at step  74000 :  4.76042498052
# Average loss at step  76000 :  4.88565437084
# Average loss at step  78000 :  4.78991894686
# Average loss at step  80000 :  4.82279447448
# Nearest to such: these, hus, well, regarded, reels, tines, many, abiding,
# Nearest to all: wct, dinar, rates, dems, both, microcebus, phi, three,
# Nearest to at: in, on, callithrix, after, dasyprocta, five, from, zorn,
# Nearest to they: he, you, there, we, it, not, who, microseconds,
# Nearest to or: and, microcebus, callithrix, michelob, dinar, heckel, primigenius, than,
# Nearest to it: he, this, she, there, which, thaler, they, altenberg,
# Nearest to zero: five, seven, eight, six, four, nine, three, callithrix,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to eight: seven, six, nine, five, four, three, zero, callithrix,
# Nearest to may: can, would, must, could, will, might, should, january,
# Nearest to were: are, was, have, had, be, been, is, thaler,
# Nearest to that: which, however, this, fanzines, callithrix, but, wct, prism,
# Nearest to over: when, wct, rational, troposphere, hyacinthus, aosta, buys, callithrix,
# Nearest to war: angiotensin, atman, farian, anxiety, before, melisende, boaz, communes,
# Nearest to used: known, heterosexuals, crb, primigenius, microcebus, considered, peacock, marmoset,
# Nearest to th: seven, four, five, six, eight, nine, three, dasyprocta,
# Average loss at step  82000 :  4.80648997808
# Average loss at step  84000 :  4.78386403358
# Average loss at step  86000 :  4.74960397458
# Average loss at step  88000 :  4.6856829493
# Average loss at step  90000 :  4.75636325133
# Nearest to such: these, well, hus, reels, abiding, regarded, many, tines,
# Nearest to all: wct, dinar, rates, both, some, dems, microcebus, phi,
# Nearest to at: in, on, after, callithrix, peacocks, during, dasyprocta, from,
# Nearest to they: he, we, there, you, it, not, who, she,
# Nearest to or: and, michelob, callithrix, dinar, but, microcebus, cebus, thibetanus,
# Nearest to it: he, this, she, there, they, which, thaler, still,
# Nearest to zero: five, seven, eight, six, nine, four, callithrix, thaler,
# Nearest to four: five, seven, six, eight, three, two, one, nine,
# Nearest to eight: seven, six, nine, five, four, three, zero, callithrix,
# Nearest to may: can, would, could, must, will, might, should, january,
# Nearest to were: are, was, have, had, be, been, is, thaler,
# Nearest to that: which, however, but, this, fanzines, prism, callithrix, wct,
# Nearest to over: when, wct, troposphere, rational, hyacinthus, buys, comprising, callithrix,
# Nearest to war: angiotensin, atman, farian, before, anxiety, melisende, communes, boaz,
# Nearest to used: known, considered, heterosexuals, microcebus, primigenius, crb, peacock, recitative,
# Nearest to th: seven, nine, six, eight, five, dasyprocta, four, finalist,
# Average loss at step  92000 :  4.71838206708
# Average loss at step  94000 :  4.61893236428
# Average loss at step  96000 :  4.73578141415
# Average loss at step  98000 :  4.6221827811
# Average loss at step  100000 :  4.67863698125
# Nearest to such: these, well, many, hus, known, regarded, reels, abiding,
# Nearest to all: wct, dinar, both, rates, some, dems, microcebus, various,
# Nearest to at: in, on, after, during, callithrix, from, zorn, through,
# Nearest to they: he, we, there, you, it, not, who, she,
# Nearest to or: and, than, callithrix, but, michelob, dinar, microcebus, dasyprocta,
# Nearest to it: he, this, she, there, they, which, thaler, altenberg,
# Nearest to zero: five, eight, seven, six, four, nine, three, callithrix,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to eight: seven, nine, five, six, four, zero, three, callithrix,
# Nearest to may: can, would, will, must, could, might, should, january,
# Nearest to were: are, was, have, had, be, is, thaler, including,
# Nearest to that: which, however, this, what, but, callithrix, fanzines, prism,
# Nearest to over: when, wct, rational, troposphere, hyacinthus, comprising, callithrix, three,
# Nearest to war: angiotensin, atman, farian, before, anxiety, melisende, communes, boaz,
# Nearest to used: known, considered, microcebus, primigenius, heterosexuals, crb, recitative, dasyprocta,
# Nearest to th: six, seven, nine, dasyprocta, five, four, eight, finalist,

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.show(filename)

try:
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt
    # %matplotlib inline

    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print("Please install sklearn and matplotlib to visualize embeddings.")
